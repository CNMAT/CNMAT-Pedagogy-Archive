# %%
import itertools as it

sensors = ["camera/kinect", "multitouch", "esplora  ", "microphone", "breath-control" ]
actuators = ["speaker", "speaker", "transd.", "transd.", "motor"]
resontators = ["room", "instrument", "paper", "cardboard", "body"]

def reshape(thelist, rows,cols):  
    return [thelist[i:i + cols] for i in range(0, len(thelist), cols)]

# %%
count = 0
for perm in zip( it.permutations(sensors), it.permutations(actuators), it.permutations(resontators)):
    count += 1
    string = ""
    print count
    for i in range(len(perm[0])):
        string = ""
        for j in range(len(perm)):
            string += perm[j][i] + '\t\t'
            
        print string
    print '\n'
# Out:
# 1
# camera/kinect		speaker		room
# multitouch		speaker		instrument
# esplora  		transd.		paper
# microphone		transd.		cardboard
# breath-control		motor		body
#
#
# 2
# camera/kinect		speaker		room
# multitouch		speaker		instrument
# esplora  		transd.		paper
# breath-control		motor		body
# microphone		transd.		cardboard
#
#
# 3
# camera/kinect		speaker		room
# multitouch		speaker		instrument
# microphone		transd.		cardboard
# esplora  		transd.		paper
# breath-control		motor		body
#
#
# 4
# camera/kinect		speaker		room
# multitouch		speaker		instrument
# microphone		transd.		cardboard
# breath-control		motor		body
# esplora  		transd.		paper
#
#
# 5
# camera/kinect		speaker		room
# multitouch		speaker		instrument
# breath-control		motor		body
# esplora  		transd.		paper
# microphone		transd.		cardboard
#
#
# 6
# camera/kinect		speaker		room
# multitouch		speaker		instrument
# breath-control		motor		body
# microphone		transd.		cardboard
# esplora  		transd.		paper
#
#
# 7
# ...

# %%
for c in list(it.combinations(range(15), 5)):
    print c #sensors[c[0]], actuators[c[1]], resontators[c[2]]
# Out:
#  (0, 1, 2, 3, 4)
# (0, 1, 2, 3, 5)
# (0, 1, 2, 3, 6)
# (0, 1, 2, 3, 7)
# (0, 1, 2, 3, 8)
# (0, 1, 2, 3, 9)
# (0, 1, 2, 3, 10)
# (0, 1, 2, 3, 11)
# (0, 1, 2, 3, 12)
# (0, 1, 2, 3, 13)
# (0, 1, 2, 3, 14)
# (0, 1, 2, 4, 5)
# (0, 1, 2, 4, 6)
# (0, 1, 2, 4, 7)
# (0, 1, 2, 4, 8)
# (0, 1, 2, 4, 9)
# (0, 1, 2, 4, 10)
# (0, 1, 2, 4, 11)
# (0, 1, 2, 4, 12)
# (0, 1, 2, 4, 13)
# (0, 1, 2, 4, 14)
# (0, 1, 2, 5, 6)
# (0, 1, 2, 5, 7)
# (0, 1, 2, 5, 8)
# (0, 1, 2, 5, 9)
# (0, 1, 2, 5, 10)
# (0, 1, 2, 5, 11)
# (0, 1, 2, 5, 12)
# (0, 1, 2, 5, 13)
# (0, 1, 2, 5, 14)
# (0, 1, 2, 6, 7)
# (0, 1, 2, 6, 8)
# (0, 1, 2, 6, 9)
# (0, 1, 2, 6, 10)
# (0, 1, 2, 6, 11)
# (0, 1, 2, 6, 12)
# (0, 1, 2, 6, 13)
# (0, 1, 2, 6, 14)
# (0, 1, 2, 7, 8)
# (0, 1, 2, 7, 9)
# (0, 1, 2, 7, 10)
# (0, 1, 2, 7, 11)
# (0, 1, 2, 7, 12)
# (0, 1, 2, 7, 13)
# (0, 1, 2, 7, 14)
# (0, 1, 2, 8, 9)
# (0, 1, 2, 8, 10)
# (0, 1, 2, 8, 11)
# (0, 1, 2, 8, 12)
# (0, 1, 2, 8, 13)
# (0, 1, 2, 8, 14)
# (0, 1, 2, 9, 10)
# (0, 1, 2, 9, 11)
# ...
